# %%
# %pip install faostat

import faostat
# Out:
# Requirement already satisfied: faostat in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (1.1.2)
# Requirement already satisfied: pandas in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from faostat) (2.2.3)
# Requirement already satisfied: requests in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from faostat) (2.32.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from pandas->faostat) (2.2.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from pandas->faostat) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from pandas->faostat) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from pandas->faostat) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from python-dateutil>=2.8.2->pandas->faostat) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from requests->faostat) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from requests->faostat) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from requests->faostat) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lenovo\miniconda3\envs\web_scrapping_env\lib\site-packages (from requests->faostat) (2025.4.26)
# Note: you may need to restart the kernel to use updated packages.

# %%
data = faostat.list_datasets()
data[1:4]
# Out:
# [('QCL',
#   'Crops and livestock products',
#   '2025-02-27',
#   'minor revision',
#   '2024-12-20 / 2025-02-27',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('QI',
#   'Production Indices',
#   '2025-02-03',
#   '',
#   '2025-02-03',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024'),
#  ('QV',
#   'Value of Agricultural Production',
#   '2025-02-03',
#   '',
#   '2025-02-03',
#   'final',
#   '2023',
#   '2025-12',
#   'final',
#   '2024')]

# %%
import os

os.makedirs('./datasets', exist_ok=True)
df = faostat.list_datasets_df()
df.to_csv('./datasets/faostat_datasets.csv', index=False)
df
# Out:
#    code                              label date_update     note_update  \
# 0   QCL       Crops and livestock products  2025-02-27  minor revision
# 1    QI                 Production Indices  2025-02-03
# 2    QV   Value of Agricultural Production  2025-02-03
# 3    FS  Suite of Food Security Indicators  2025-03-27  minor revision
# 4   FBS              Food Balances (2010-)  2024-07-19
# ..  ...                                ...         ...             ...
# 63   FA           Food Aid Shipments (WFP)  2016-12-22
# 64   RM                          Machinery  2021-12-03  minor revision
# 65   RY                  Machinery Archive  2021-12-03  minor revision
# 66   RA                Fertilizers archive  2020-09-08  minor revision
# 67   PA       Producer Prices (old series)  1991-12-31
#
#             release_current state_current year_current release_next  \
# 0   2024-12-20 / 2025-02-27         final         2023      2025-12
# 1                2025-02-03         final         2023      2025-12
# 2                2025-02-03         final         2023      2025-12
# 3   2024-07-24 / 2025-03-27         final         2023      2025-07
# 4                2024-07-19         final         2022      2025-07
# ..                      ...           ...          ...          ...
# 63               2016-12-22   preliminary         2016
# 64  2011-12-22 / 2021-12-03         final         2009
# 65  2006-12-31 / 2021-12-03         final         2005
# 66  2013-12-31 / 2020-09-08         final         2002
# 67               1991-12-31         final         1990
#
#    state_next year_next
# 0       final      2024
# 1       final      2024
# 2       final      2024
# 3       final      2024
# 4       final      2023
# ..        ...       ...
# 63
# 64
# 65
# 66
# 67
#
# [68 rows x 10 columns]

# %%
y = faostat.get_par_df('RM', 'specialgroups')
y
# Out:
#                                                 label   code aggregate_type
# 0                       European Union (27) + (Total)   5707              +
# 1                        European Union (27) > (List)  5707>              >
# 2          Least Developed Countries (LDCs) + (Total)   5801              +
# 3           Least Developed Countries (LDCs) > (List)  5801>              >
# 4   Land Locked Developing Countries (LLDCs) + (To...   5802              +
# 5   Land Locked Developing Countries (LLDCs) > (List)  5802>              >
# 6     Small Island Developing States (SIDS) + (Total)   5803              +
# 7      Small Island Developing States (SIDS) > (List)  5803>              >
# 8   Low Income Food Deficit Countries (LIFDCs) + (...   5815              +
# 9   Low Income Food Deficit Countries (LIFDCs) > (...  5815>              >
# 10  Net Food Importing Developing Countries (NFIDC...   5817              +
# 11  Net Food Importing Developing Countries (NFIDC...  5817>              >

# %%
mypars = {'element':[2312, 2313],'item':'221'}
data = faostat.get_data('QCL', pars=mypars)
data[40:44]

# get data in a dataframe
df = faostat.get_data_df('QCL', pars=mypars)
# df.to_csv('./datasets/faostat_data_crops.csv', index=False)

# %%
df.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code', 'Area', 'Element Code', 'Element',
#        'Item Code', 'Item', 'Year Code', 'Year', 'Unit', 'Value'],
#       dtype='object')

# %%
df = df[['Domain','Area', 'Element','Item', 'Year', 'Unit', 'Value']]
df.to_csv('./datasets/faostat_data_crops.csv', index=False)
